# %% [markdown]
# # Практическое задание №6

# %% [markdown]
# - Попробуйте обучить нейронную сеть U-Net на любом другом датасете.
# - Опишите результат. Что помогло повысить точность?
# - *Попробуйте свои силы в задаче City Scapes на Kaggle - https://www.kaggle.com/dansbecker/cityscapes-image-pairs.
# - *Сделайте свою реализацию U-Net на TensorFlow

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2DTranspose, concatenate, Activation, MaxPooling2D, Conv2D, BatchNormalization
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam, SGD
# from tensorflow.keras import utils
import matplotlib.pyplot as plt
# from tensorflow.keras.preprocessing import image
# from tensorflow.keras.applications import VGG16
import numpy as np
import os
from PIL import Image, ImageOps
from sklearn.cluster import KMeans
# from tensorflow.keras.utils import plot_model
# from tensorflow.keras.callbacks import EarlyStopping

import tensorflow as tf

# метрика Dice Coefficient
def dice_coef(y_true, y_pred):
    return (2. * K.sum(y_true * y_pred) + 1.) / (K.sum(y_true) + K.sum(y_pred) + 1.)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
image_dir_val = '/content/drive/MyDrive/05_neurals/06/cityscapes_data/train/'
image_dir_train = '/content/drive/MyDrive/05_neurals/06/cityscapes_data/val/'

# %%
import os, fnmatch
images_train = os.listdir(image_dir_train)
images_val = os.listdir(image_dir_val)

# %% [markdown]
# Датасет Cityscapes. В данном датасете присутствуют исходные и сегментированные изображения.
# https://www.kaggle.com/datasets/dansbecker/cityscapes-image-pairs?resource=download

# %%
num_images_train = 80
num_images_val = 20

X_train = []
y_train = []

X_val = []
y_val = []

# image_dir_train = 'cityscapes_data/train'
# image_dir_val = 'cityscapes_data/val'
# images_train = os.listdir(image_dir_train)
# images_val = os.listdir(image_dir_val)

# %%
for filename in images_train[:num_images_train]:
    image = Image.open(os.path.join(image_dir_train, filename))
    X_train.append(np.asarray(ImageOps.crop(image, (0, 0, 256, 0))))
    y_train.append(np.asarray(ImageOps.crop(image, (256, 0, 0, 0))))
    

for filename in images_val[:num_images_val]:
    image = Image.open(os.path.join(image_dir_val, filename))
    X_val.append(np.asarray(ImageOps.crop(image, (0, 0, 256, 0))))
    y_val.append(np.asarray(ImageOps.crop(image, (256, 0, 0, 0))))


X_train = np.array(X_train) / 255.
X_val = np.array(X_val) / 255.

y_train = np.array(y_train)
y_val = np.array(y_val)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes[0].imshow(X_train[3])
axes[1].imshow(y_train[3])

# %%
num_items = 1000
color_array = np.random.choice(range(256), 3*num_items).reshape(-1,3)

# количество классов установил методом подбора
num_classes = 19
label_model = KMeans(n_clusters=num_classes, random_state=21)
label_model.fit(color_array)
# Out:
# KMeans(n_clusters=19, random_state=21)

# %%
label_class = label_model.predict(y_train[3].reshape(-1, 3)).reshape(256, 256)
fig, axes = plt.subplots(1, 3, figsize=(18, 9))
axes[0].imshow(X_train[3])
axes[1].imshow(y_train[3])
axes[2].imshow(label_class)
plt.show()

# %%
def Color2index(y, num_classes=19):
    arr_col = np.arange(0, num_classes)
    t = label_model.predict(y.reshape(-1, 3)).reshape(256, 256)
    y_cat = (arr_col == t[...,None]).astype(int)
    return y_cat, t

cat_yi,ind_yi = Color2index(y_train[3])

class_ = 0
fig, axes = plt.subplots(1, 2, figsize=(18, 9))
axes[0].imshow(y_train[3,:,:,:])
axes[0].title.set_text('Целевая разметка')
axes[1].imshow(cat_yi[:,:,class_])
axes[1].title.set_text(f'Целевая разметка для класса {class_}')
plt.show()

# %%
train_labels = []
val_labels = []

for mask in y_train:
    y_cat,_ = Color2index(mask)
    train_labels.append(y_cat)


for mask in y_val:
    y_cat,_ = Color2index(mask)
    val_labels.append(y_cat)
    
train_labels = np.array(train_labels)
val_labels = np.array(val_labels)

# %%
train_labels.shape
# Out:
# (20, 256, 256, 19)

# %% [markdown]
# ## Базовая модель

# %%
def Unet(num_classes=19, input_shape=(256, 256, 3), act_func='relu'):
    img_input = Input(input_shape)

    # Block 1
    x = Conv2D(64, (3, 3), padding='same', name='block1_conv1')(img_input)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    x = Conv2D(64, (3, 3), padding='same', name='block1_conv2')(x)
    x = BatchNormalization()(x)
    # запомним тензор для переноса
    block_1_out = Activation(act_func)(x)

    x = MaxPooling2D()(block_1_out) 

    # Block 2
    x = Conv2D(128, (3, 3), padding='same', name='block2_conv1')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    x = Conv2D(128, (3, 3), padding='same', name='block2_conv2')(x)
    x = BatchNormalization()(x)
    # запомним тензор для переноса
    block_2_out = Activation(act_func)(x)

    x = MaxPooling2D()(block_2_out) 

    # Block 3
    x = Conv2D(256, (3, 3), padding='same', name='block3_conv1')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    x = Conv2D(256, (3, 3), padding='same', name='block3_conv2')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    x = Conv2D(256, (3, 3), padding='same', name='block3_conv3')(x)
    x = BatchNormalization()(x)
    # запомним тензор для переноса
    block_3_out = Activation(act_func)(x)

    x = MaxPooling2D()(block_3_out) 

    # Block 4
    x = Conv2D(512, (3, 3), padding='same', name='block4_conv1')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    x = Conv2D(512, (3, 3), padding='same', name='block4_conv2')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    x = Conv2D(512, (3, 3), padding='same', name='block4_conv3')(x)
    x = BatchNormalization()(x)
    # запомним тензор для переноса
    block_4_out = Activation(act_func)(x)

    # UP 1
    x = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    # добавили перенос из понижаюшего плеча
    x = concatenate([x, block_3_out])
    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    # UP 2
    x = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(x) 
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    # добавили перенос из понижаюшего плеча
    x = concatenate([x, block_2_out])
    x = Conv2D(128, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    x = Conv2D(128, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    # UP 3
    x = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    # добавили перенос из понижаюшего плеча
    x = concatenate([x, block_1_out])
    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    # слой классификатор
    x = Conv2D(num_classes, (3, 3), activation='softmax', padding='same')(x)

    model = Model(img_input, x)
    model.compile(optimizer=Adam(),
                  loss='categorical_crossentropy',
                  metrics=[dice_coef])
    model.summary()
    return model

# %%
super_model = Unet(19, (256, 256, 3))
# plot_model(super_model, to_file='super_model.png', show_shapes=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 256, 256, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 64  256        ['block1_conv1[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 256, 256, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 256, 256, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 64  256        ['block1_conv2[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 256, 256, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 64  0           ['activation_1[0][0]']
#                                 )
#
#  block2_conv1 (Conv2D)          (None, 128, 128, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 12  512        ['block2_conv1[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  block2_conv2 (Conv2D)          (None, 128, 128, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 12  512        ['block2_conv2[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['activation_3[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 64, 64, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 256)  1024       ['block3_conv1[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_4[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 64, 64, 256)  590080      ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 256)  1024       ['block3_conv2[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_5[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 64, 64, 256)  590080      ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 256)  1024       ['block3_conv3[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_6[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0          ['activation_6[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 32, 32, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 512)  2048       ['block4_conv1[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_7[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 32, 32, 512)  2359808     ['activation_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 512)  2048       ['block4_conv2[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_8[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 32, 32, 512)  2359808     ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 512)  2048       ['block4_conv3[0][0]']
#  rmalization)
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 256)  524544     ['batch_normalization_9[0][0]']
#  ose)
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_transpose[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_10[0][0]']
#
#  concatenate (Concatenate)      (None, 64, 64, 512)  0           ['activation_10[0][0]',
#                                                                   'activation_6[0][0]']
#
#  conv2d (Conv2D)                (None, 64, 64, 256)  1179904     ['concatenate[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 256)  1024       ['conv2d[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 256)  590080      ['activation_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_1[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 12  131200     ['activation_12[0][0]']
#  spose)                         8)
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 12  512        ['conv2d_transpose_1[0][0]']
#  ormalization)                  8)
#
#  activation_13 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_13[0][0]']
#                                 8)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 25  0           ['activation_13[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 12  295040      ['concatenate_1[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 128, 128, 12  512        ['conv2d_2[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 128, 128, 12  512        ['conv2d_3[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  batch_normalization_16 (BatchN  (None, 256, 256, 64  256        ['conv2d_transpose_2[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 12  0           ['activation_16[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 256, 256, 64  73792       ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 256, 256, 64  256        ['conv2d_4[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 256, 256, 64  36928       ['activation_17[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 256, 256, 64  256        ['conv2d_5[0][0]']
#  ormalization)                  )
#
#  activation_18 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 256, 256, 19  10963       ['activation_18[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 10,674,259
# Trainable params: 10,666,195
# Non-trainable params: 8,064
# __________________________________________________________________________________________________

# %%
def callbacks(patience=5):
    checkpoint = tf.keras.callbacks.ModelCheckpoint('super_model.h5', monitor='loss', verbose=1, save_best_only=True, save_weights_only=True)
    early=tf.keras.callbacks.EarlyStopping(monitor='loss',patience=patience)
    callbacks_list=[checkpoint, early]
    return callbacks_list

# %%
# %%time

history = super_model.fit(X_train, train_labels, epochs=40, batch_size=2, validation_data=(X_val, val_labels), callbacks=callbacks())
# Out:
# Epoch 1/40
# 10/10 [==============================] - ETA: 0s - loss: 2.1620 - dice_coef: 0.2336
# Epoch 1: loss improved from inf to 2.16197, saving model to super_model.h5
# 10/10 [==============================] - 16s 645ms/step - loss: 2.1620 - dice_coef: 0.2336 - val_loss: 3.2952 - val_dice_coef: 0.0595
# Epoch 2/40
# 10/10 [==============================] - ETA: 0s - loss: 1.4200 - dice_coef: 0.3978
# Epoch 2: loss improved from 2.16197 to 1.41999, saving model to super_model.h5
# 10/10 [==============================] - 5s 564ms/step - loss: 1.4200 - dice_coef: 0.3978 - val_loss: 2.7390 - val_dice_coef: 0.0749
# Epoch 3/40
# 10/10 [==============================] - ETA: 0s - loss: 1.2675 - dice_coef: 0.4861
# Epoch 3: loss improved from 1.41999 to 1.26746, saving model to super_model.h5
# 10/10 [==============================] - 7s 692ms/step - loss: 1.2675 - dice_coef: 0.4861 - val_loss: 2.5927 - val_dice_coef: 0.0953
# Epoch 4/40
# 10/10 [==============================] - ETA: 0s - loss: 1.2426 - dice_coef: 0.4794
# Epoch 4: loss improved from 1.26746 to 1.24262, saving model to super_model.h5
# 10/10 [==============================] - 7s 692ms/step - loss: 1.2426 - dice_coef: 0.4794 - val_loss: 2.0547 - val_dice_coef: 0.1703
# Epoch 5/40
# 10/10 [==============================] - ETA: 0s - loss: 1.1473 - dice_coef: 0.5218
# Epoch 5: loss improved from 1.24262 to 1.14730, saving model to super_model.h5
# 10/10 [==============================] - 5s 564ms/step - loss: 1.1473 - dice_coef: 0.5218 - val_loss: 2.1582 - val_dice_coef: 0.2999
# Epoch 6/40
# 10/10 [==============================] - ETA: 0s - loss: 1.1110 - dice_coef: 0.5066
# Epoch 6: loss improved from 1.14730 to 1.11104, saving model to super_model.h5
# 10/10 [==============================] - 5s 564ms/step - loss: 1.1110 - dice_coef: 0.5066 - val_loss: 2.2103 - val_dice_coef: 0.2975
# Epoch 7/40
# 10/10 [==============================] - ETA: 0s - loss: 1.0828 - dice_coef: 0.5267
# Epoch 7: loss improved from 1.11104 to 1.08279, saving model to super_model.h5
# 10/10 [==============================] - 5s 566ms/step - loss: 1.0828 - dice_coef: 0.5267 - val_loss: 2.5311 - val_dice_coef: 0.3272
# Epoch 8/40
# 10/10 [==============================] - ETA: 0s - loss: 1.0540 - dice_coef: 0.5357
# Epoch 8: loss improved from 1.08279 to 1.05404, saving model to super_model.h5
# 10/10 [==============================] - 7s 693ms/step - loss: 1.0540 - dice_coef: 0.5357 - val_loss: 3.1496 - val_dice_coef: 0.3665
# Epoch 9/40
# 10/10 [==============================] - ETA: 0s - loss: 1.0294 - dice_coef: 0.5529
# Epoch 9: loss improved from 1.05404 to 1.02935, saving model to super_model.h5
# 10/10 [==============================] - 5s 568ms/step - loss: 1.0294 - dice_coef: 0.5529 - val_loss: 3.9700 - val_dice_coef: 0.3806
# Epoch 10/40
# 10/10 [==============================] - ETA: 0s - loss: 1.0452 - dice_coef: 0.5443
# Epoch 10: loss did not improve from 1.02935
# 10/10 [==============================] - 6s 670ms/step - loss: 1.0452 - dice_coef: 0.5443 - val_loss: 4.0613 - val_dice_coef: 0.3820
# Epoch 11/40
# 10/10 [==============================] - ETA: 0s - loss: 1.0390 - dice_coef: 0.5326
# Epoch 11: loss did not improve from 1.02935
# 10/10 [==============================] - 5s 545ms/step - loss: 1.0390 - dice_coef: 0.5326 - val_loss: 5.2757 - val_dice_coef: 0.3867
# Epoch 12/40
# 10/10 [==============================] - ETA: 0s - loss: 1.0237 - dice_coef: 0.5516
# Epoch 12: loss improved from 1.02935 to 1.02369, saving model to super_model.h5
# 10/10 [==============================] - 7s 696ms/step - loss: 1.0237 - dice_coef: 0.5516 - val_loss: 4.8217 - val_dice_coef: 0.3865
# Epoch 13/40
# 10/10 [==============================] - ETA: 0s - loss: 0.9820 - dice_coef: 0.5698
# Epoch 13: loss improved from 1.02369 to 0.98205, saving model to super_model.h5
# 10/10 [==============================] - 7s 695ms/step - loss: 0.9820 - dice_coef: 0.5698 - val_loss: 5.6306 - val_dice_coef: 0.3898
# Epoch 14/40
# 10/10 [==============================] - ETA: 0s - loss: 0.9755 - dice_coef: 0.5605
# Epoch 14: loss improved from 0.98205 to 0.97549, saving model to super_model.h5
# 10/10 [==============================] - 6s 572ms/step - loss: 0.9755 - dice_coef: 0.5605 - val_loss: 4.9955 - val_dice_coef: 0.3878
# Epoch 15/40
# 10/10 [==============================] - ETA: 0s - loss: 0.9608 - dice_coef: 0.5697
# Epoch 15: loss improved from 0.97549 to 0.96077, saving model to super_model.h5
# 10/10 [==============================] - 7s 696ms/step - loss: 0.9608 - dice_coef: 0.5697 - val_loss: 5.8191 - val_dice_coef: 0.3923
# Epoch 16/40
# 10/10 [==============================] - ETA: 0s - loss: 0.9593 - dice_coef: 0.5761
# Epoch 16: loss improved from 0.96077 to 0.95930, saving model to super_model.h5
# 10/10 [==============================] - 7s 695ms/step - loss: 0.9593 - dice_coef: 0.5761 - val_loss: 5.9404 - val_dice_coef: 0.3911
# Epoch 17/40
# 10/10 [==============================] - ETA: 0s - loss: 0.9332 - dice_coef: 0.5795
# Epoch 17: loss improved from 0.95930 to 0.93323, saving model to super_model.h5
# 10/10 [==============================] - 6s 571ms/step - loss: 0.9332 - dice_coef: 0.5795 - val_loss: 5.7533 - val_dice_coef: 0.3918
# Epoch 18/40
# 10/10 [==============================] - ETA: 0s - loss: 0.9411 - dice_coef: 0.5782
# Epoch 18: loss did not improve from 0.93323
# 10/10 [==============================] - 5s 546ms/step - loss: 0.9411 - dice_coef: 0.5782 - val_loss: 6.2022 - val_dice_coef: 0.3932
# Epoch 19/40
# 10/10 [==============================] - ETA: 0s - loss: 0.9569 - dice_coef: 0.5684
# Epoch 19: loss did not improve from 0.93323
# 10/10 [==============================] - 6s 671ms/step - loss: 0.9569 - dice_coef: 0.5684 - val_loss: 5.6112 - val_dice_coef: 0.3926
# Epoch 20/40
# 10/10 [==============================] - ETA: 0s - loss: 0.9546 - dice_coef: 0.5776
# Epoch 20: loss did not improve from 0.93323
# 10/10 [==============================] - 6s 670ms/step - loss: 0.9546 - dice_coef: 0.5776 - val_loss: 6.5299 - val_dice_coef: 0.3902
# Epoch 21/40
# 10/10 [==============================] - ETA: 0s - loss: 0.8917 - dice_coef: 0.5918
# Epoch 21: loss improved from 0.93323 to 0.89167, saving model to super_model.h5
# 10/10 [==============================] - 6s 571ms/step - loss: 0.8917 - dice_coef: 0.5918 - val_loss: 6.9286 - val_dice_coef: 0.3932
# Epoch 22/40
# 10/10 [==============================] - ETA: 0s - loss: 0.9123 - dice_coef: 0.5888
# Epoch 22: loss did not improve from 0.89167
# 10/10 [==============================] - 5s 545ms/step - loss: 0.9123 - dice_coef: 0.5888 - val_loss: 6.1338 - val_dice_coef: 0.3931
# Epoch 23/40
# 10/10 [==============================] - ETA: 0s - loss: 0.8925 - dice_coef: 0.5910
# Epoch 23: loss did not improve from 0.89167
# 10/10 [==============================] - 5s 543ms/step - loss: 0.8925 - dice_coef: 0.5910 - val_loss: 5.4390 - val_dice_coef: 0.3848
# Epoch 24/40
# 10/10 [==============================] - ETA: 0s - loss: 0.8886 - dice_coef: 0.6008
# Epoch 24: loss improved from 0.89167 to 0.88862, saving model to super_model.h5
# 10/10 [==============================] - 6s 570ms/step - loss: 0.8886 - dice_coef: 0.6008 - val_loss: 6.4520 - val_dice_coef: 0.3914
# Epoch 25/40
# 10/10 [==============================] - ETA: 0s - loss: 0.8770 - dice_coef: 0.6012
# Epoch 25: loss improved from 0.88862 to 0.87699, saving model to super_model.h5
# 10/10 [==============================] - 7s 695ms/step - loss: 0.8770 - dice_coef: 0.6012 - val_loss: 6.7275 - val_dice_coef: 0.3951
# Epoch 26/40
# 10/10 [==============================] - ETA: 0s - loss: 0.8726 - dice_coef: 0.6016
# Epoch 26: loss improved from 0.87699 to 0.87257, saving model to super_model.h5
# 10/10 [==============================] - 6s 569ms/step - loss: 0.8726 - dice_coef: 0.6016 - val_loss: 5.4944 - val_dice_coef: 0.3800
# Epoch 27/40
# 10/10 [==============================] - ETA: 0s - loss: 0.8597 - dice_coef: 0.6020
# Epoch 27: loss improved from 0.87257 to 0.85972, saving model to super_model.h5
# 10/10 [==============================] - 6s 569ms/step - loss: 0.8597 - dice_coef: 0.6020 - val_loss: 5.7643 - val_dice_coef: 0.3894
# Epoch 28/40
# 10/10 [==============================] - ETA: 0s - loss: 0.8285 - dice_coef: 0.6189
# Epoch 28: loss improved from 0.85972 to 0.82849, saving model to super_model.h5
# 10/10 [==============================] - 7s 696ms/step - loss: 0.8285 - dice_coef: 0.6189 - val_loss: 5.8738 - val_dice_coef: 0.3900
# Epoch 29/40
# 10/10 [==============================] - ETA: 0s - loss: 0.8304 - dice_coef: 0.6120
# Epoch 29: loss did not improve from 0.82849
# 10/10 [==============================] - 5s 543ms/step - loss: 0.8304 - dice_coef: 0.6120 - val_loss: 6.6035 - val_dice_coef: 0.3952
# Epoch 30/40
# 10/10 [==============================] - ETA: 0s - loss: 0.8311 - dice_coef: 0.6198
# Epoch 30: loss did not improve from 0.82849
# 10/10 [==============================] - 6s 672ms/step - loss: 0.8311 - dice_coef: 0.6198 - val_loss: 4.9914 - val_dice_coef: 0.3962
# Epoch 31/40
# 10/10 [==============================] - ETA: 0s - loss: 0.8502 - dice_coef: 0.6184
# Epoch 31: loss did not improve from 0.82849
# 10/10 [==============================] - 5s 544ms/step - loss: 0.8502 - dice_coef: 0.6184 - val_loss: 6.3562 - val_dice_coef: 0.3963
# Epoch 32/40
# 10/10 [==============================] - ETA: 0s - loss: 0.8461 - dice_coef: 0.6031
# Epoch 32: loss did not improve from 0.82849
# 10/10 [==============================] - 6s 671ms/step - loss: 0.8461 - dice_coef: 0.6031 - val_loss: 4.6882 - val_dice_coef: 0.3809
# Epoch 33/40
# 10/10 [==============================] - ETA: 0s - loss: 0.8419 - dice_coef: 0.6180
# Epoch 33: loss did not improve from 0.82849
# 10/10 [==============================] - 5s 544ms/step - loss: 0.8419 - dice_coef: 0.6180 - val_loss: 5.9853 - val_dice_coef: 0.3950
# CPU times: user 3min 9s, sys: 3.42 s, total: 3min 12s
# Wall time: 3min 26s

# %%
plt.figure(figsize=(18, 9))
plt.plot(history.history['val_dice_coef'],label = 'test')
plt.plot(history.history['dice_coef'],label='train')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('dice_coef')
plt.show()

# %% [markdown]
# Дальше 0,37 тест метрики похоже не улучшаются

# %% [markdown]
# ## Тюнинг модели

# %% [markdown]
# Пробую изменять функцию активации, оптимизатор, коэффициент скорости обучения, количество ядер, количество слоев.

# %%
def Unet(num_classes=19, input_shape=(256, 256, 3), act_func='relu'):
    img_input = Input(input_shape)

    # Block 1
    x = Conv2D(32, (3, 3), padding='same', name='block1_conv1')(img_input)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    x = Conv2D(32, (3, 3), padding='same', name='block1_conv2')(x)
    x = BatchNormalization()(x)
    # запомним тензор для переноса
    block_1_out = Activation(act_func)(x)

    x = MaxPooling2D()(block_1_out) 

    # Block 2
    x = Conv2D(64, (3, 3), padding='same', name='block2_conv1')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    x = Conv2D(64, (3, 3), padding='same', name='block2_conv2')(x)
    x = BatchNormalization()(x)
    # запомним тензор для переноса
    block_2_out = Activation(act_func)(x)

    x = MaxPooling2D()(block_2_out) 

    # Block 3
    x = Conv2D(128, (3, 3), padding='same', name='block3_conv1')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    x = Conv2D(128, (3, 3), padding='same', name='block3_conv2')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    x = Conv2D(128, (3, 3), padding='same', name='block3_conv3')(x)
    x = BatchNormalization()(x)
    # запомним тензор для переноса
    block_3_out = Activation(act_func)(x)

    x = MaxPooling2D()(block_3_out) 

    # Block 4
    x = Conv2D(256, (3, 3), padding='same', name='block4_conv1')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    x = Conv2D(256, (3, 3), padding='same', name='block4_conv2')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    x = Conv2D(256, (3, 3), padding='same', name='block4_conv3')(x)
    x = BatchNormalization()(x)
    # запомним тензор для переноса
    block_4_out = Activation(act_func)(x)
    
    x = MaxPooling2D()(block_4_out)
    
    # Block 5
    x = Conv2D(512, (3, 3), padding='same', name='block5_conv1')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    x = Conv2D(512, (3, 3), padding='same', name='block5_conv2')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    x = Conv2D(512, (3, 3), padding='same', name='block5_conv3')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    # UP 1
    x = Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    # добавили перенос из понижаюшего плеча
    x = concatenate([x, block_4_out])
    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    x = Conv2D(512, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    # UP 2
    x = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(x) 
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    # добавили перенос из понижаюшего плеча
    x = concatenate([x, block_3_out])
    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    # UP 3
    x = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    # добавили перенос из понижаюшего плеча
    x = concatenate([x, block_2_out])
    x = Conv2D(128, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    x = Conv2D(128, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    # UP 4
    x = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    # добавили перенос из понижаюшего плеча
    x = concatenate([x, block_1_out])
    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x)

    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation(act_func)(x) 
    
    
    # слой классификатор
    x = Conv2D(num_classes, (1, 1), activation='softmax', padding='same')(x)

    model = Model(img_input, x)
    model.compile(optimizer=SGD(learning_rate=1e-2),
#                   optimizer=Adam(),
                  loss='categorical_crossentropy',
                  metrics=[dice_coef])
    model.summary()
    return model

# %%
super_model = Unet(19, (256, 256, 3), act_func='relu')
# plot_model(super_model, to_file='super_model.png', show_shapes=True)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 256, 256, 32  896         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 256, 256, 32  128        ['block1_conv1[0][0]']
#  ormalization)                  )
#
#  activation_19 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_19[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 256, 256, 32  9248        ['activation_19[0][0]']
#                                 )
#
#  batch_normalization_20 (BatchN  (None, 256, 256, 32  128        ['block1_conv2[0][0]']
#  ormalization)                  )
#
#  activation_20 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_20[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 128, 128, 32  0          ['activation_20[0][0]']
#                                 )
#
#  block2_conv1 (Conv2D)          (None, 128, 128, 64  18496       ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_21 (BatchN  (None, 128, 128, 64  256        ['block2_conv1[0][0]']
#  ormalization)                  )
#
#  activation_21 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_21[0][0]']
#                                 )
#
#  block2_conv2 (Conv2D)          (None, 128, 128, 64  36928       ['activation_21[0][0]']
#                                 )
#
#  batch_normalization_22 (BatchN  (None, 128, 128, 64  256        ['block2_conv2[0][0]']
#  ormalization)                  )
#
#  activation_22 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_22[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 64, 64, 64)  0           ['activation_22[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 64, 64, 128)  73856       ['max_pooling2d_4[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 64, 64, 128)  512        ['block3_conv1[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_23[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 64, 64, 128)  147584      ['activation_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 64, 64, 128)  512        ['block3_conv2[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_24[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 64, 64, 128)  147584      ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 64, 64, 128)  512        ['block3_conv3[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_25[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 32, 32, 128)  0          ['activation_25[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 32, 32, 256)  295168      ['max_pooling2d_5[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 32, 32, 256)  1024       ['block4_conv1[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_26[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 32, 32, 256)  590080      ['activation_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 32, 32, 256)  1024       ['block4_conv2[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_27[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 32, 32, 256)  590080      ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 32, 32, 256)  1024       ['block4_conv3[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_28[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 256)  0          ['activation_28[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 16, 16, 512)  1180160     ['max_pooling2d_6[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 16, 16, 512)  2048       ['block5_conv1[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_29[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 16, 16, 512)  2359808     ['activation_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 16, 16, 512)  2048       ['block5_conv2[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_30[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 16, 16, 512)  2359808     ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 16, 16, 512)  2048       ['block5_conv3[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 32, 32, 512)  1049088    ['activation_31[0][0]']
#  spose)
#
#  batch_normalization_32 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_transpose_3[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_32[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 32, 32, 768)  0           ['activation_32[0][0]',
#                                                                   'activation_28[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 256)  1769728     ['concatenate_3[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_7[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 512)  1180160     ['activation_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_8[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 64, 64, 256)  524544     ['activation_34[0][0]']
#  spose)
#
#  batch_normalization_35 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_transpose_4[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_35[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 64, 64, 384)  0           ['activation_35[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 256)  884992      ['concatenate_4[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_9[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_37[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 128, 128, 12  131200     ['activation_37[0][0]']
#  spose)                         8)
#
#  batch_normalization_38 (BatchN  (None, 128, 128, 12  512        ['conv2d_transpose_5[0][0]']
#  ormalization)                  8)
#
#  activation_38 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_38[0][0]']
#                                 8)
#
#  concatenate_5 (Concatenate)    (None, 128, 128, 19  0           ['activation_38[0][0]',
#                                 2)                                'activation_22[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 128, 128, 12  221312      ['concatenate_5[0][0]']
#                                 8)
#
#  batch_normalization_39 (BatchN  (None, 128, 128, 12  512        ['conv2d_11[0][0]']
#  ormalization)                  8)
#
#  activation_39 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_39[0][0]']
#                                 8)
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 12  147584      ['activation_39[0][0]']
#                                 8)
#
#  batch_normalization_40 (BatchN  (None, 128, 128, 12  512        ['conv2d_12[0][0]']
#  ormalization)                  8)
#
#  activation_40 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_40[0][0]']
#                                 8)
#
#  conv2d_transpose_6 (Conv2DTran  (None, 256, 256, 64  32832      ['activation_40[0][0]']
#  spose)                         )
#
#  batch_normalization_41 (BatchN  (None, 256, 256, 64  256        ['conv2d_transpose_6[0][0]']
#  ormalization)                  )
#
#  activation_41 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_41[0][0]']
#                                 )
#
#  concatenate_6 (Concatenate)    (None, 256, 256, 96  0           ['activation_41[0][0]',
#                                 )                                 'activation_20[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 256, 256, 64  55360       ['concatenate_6[0][0]']
#                                 )
#
#  batch_normalization_42 (BatchN  (None, 256, 256, 64  256        ['conv2d_13[0][0]']
#  ormalization)                  )
#
#  activation_42 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_42[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 64  36928       ['activation_42[0][0]']
#                                 )
#
#  batch_normalization_43 (BatchN  (None, 256, 256, 64  256        ['conv2d_14[0][0]']
#  ormalization)                  )
#
#  activation_43 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_43[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 19  1235        ['activation_43[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 14,456,755
# Trainable params: 14,445,747
# Non-trainable params: 11,008
# __________________________________________________________________________________________________

# %%
# %%time

history = super_model.fit(X_train, train_labels, epochs=70, batch_size=2, validation_data=(X_val, val_labels), callbacks=callbacks())
# Out:
# Epoch 1/70
# 10/10 [==============================] - ETA: 0s - loss: 3.2419 - dice_coef: 0.0606
# Epoch 1: loss improved from inf to 3.24193, saving model to super_model.h5
# 10/10 [==============================] - 12s 572ms/step - loss: 3.2419 - dice_coef: 0.0606 - val_loss: 2.8997 - val_dice_coef: 0.0551
# Epoch 2/70
# 10/10 [==============================] - ETA: 0s - loss: 2.7869 - dice_coef: 0.1003
# Epoch 2: loss improved from 3.24193 to 2.78686, saving model to super_model.h5
# 10/10 [==============================] - 5s 479ms/step - loss: 2.7869 - dice_coef: 0.1003 - val_loss: 2.8233 - val_dice_coef: 0.0598
# Epoch 3/70
# 10/10 [==============================] - ETA: 0s - loss: 2.4698 - dice_coef: 0.1515
# Epoch 3: loss improved from 2.78686 to 2.46975, saving model to super_model.h5
# 10/10 [==============================] - 4s 458ms/step - loss: 2.4698 - dice_coef: 0.1515 - val_loss: 2.7238 - val_dice_coef: 0.0677
# Epoch 4/70
# 10/10 [==============================] - ETA: 0s - loss: 2.2545 - dice_coef: 0.1927
# Epoch 4: loss improved from 2.46975 to 2.25451, saving model to super_model.h5
# 10/10 [==============================] - 4s 461ms/step - loss: 2.2545 - dice_coef: 0.1927 - val_loss: 2.6215 - val_dice_coef: 0.0787
# Epoch 5/70
# 10/10 [==============================] - ETA: 0s - loss: 2.0951 - dice_coef: 0.2270
# Epoch 5: loss improved from 2.25451 to 2.09508, saving model to super_model.h5
# 10/10 [==============================] - 4s 459ms/step - loss: 2.0951 - dice_coef: 0.2270 - val_loss: 2.5229 - val_dice_coef: 0.0935
# Epoch 6/70
# 10/10 [==============================] - ETA: 0s - loss: 1.9886 - dice_coef: 0.2513
# Epoch 6: loss improved from 2.09508 to 1.98864, saving model to super_model.h5
# 10/10 [==============================] - 5s 480ms/step - loss: 1.9886 - dice_coef: 0.2513 - val_loss: 2.4422 - val_dice_coef: 0.1102
# Epoch 7/70
# 10/10 [==============================] - ETA: 0s - loss: 1.8842 - dice_coef: 0.2729
# Epoch 7: loss improved from 1.98864 to 1.88415, saving model to super_model.h5
# 10/10 [==============================] - 4s 457ms/step - loss: 1.8842 - dice_coef: 0.2729 - val_loss: 2.3763 - val_dice_coef: 0.1299
# Epoch 8/70
# 10/10 [==============================] - ETA: 0s - loss: 1.8173 - dice_coef: 0.2867
# Epoch 8: loss improved from 1.88415 to 1.81729, saving model to super_model.h5
# 10/10 [==============================] - 5s 478ms/step - loss: 1.8173 - dice_coef: 0.2867 - val_loss: 2.3292 - val_dice_coef: 0.1498
# Epoch 9/70
# 10/10 [==============================] - ETA: 0s - loss: 1.7475 - dice_coef: 0.3076
# Epoch 9: loss improved from 1.81729 to 1.74753, saving model to super_model.h5
# 10/10 [==============================] - 4s 459ms/step - loss: 1.7475 - dice_coef: 0.3076 - val_loss: 2.2990 - val_dice_coef: 0.1722
# Epoch 10/70
# 10/10 [==============================] - ETA: 0s - loss: 1.7007 - dice_coef: 0.3167
# Epoch 10: loss improved from 1.74753 to 1.70070, saving model to super_model.h5
# 10/10 [==============================] - 4s 456ms/step - loss: 1.7007 - dice_coef: 0.3167 - val_loss: 2.2863 - val_dice_coef: 0.1921
# Epoch 11/70
# 10/10 [==============================] - ETA: 0s - loss: 1.6358 - dice_coef: 0.3298
# Epoch 11: loss improved from 1.70070 to 1.63582, saving model to super_model.h5
# 10/10 [==============================] - 5s 479ms/step - loss: 1.6358 - dice_coef: 0.3298 - val_loss: 2.2815 - val_dice_coef: 0.2118
# Epoch 12/70
# 10/10 [==============================] - ETA: 0s - loss: 1.5884 - dice_coef: 0.3429
# Epoch 12: loss improved from 1.63582 to 1.58840, saving model to super_model.h5
# 10/10 [==============================] - 4s 457ms/step - loss: 1.5884 - dice_coef: 0.3429 - val_loss: 2.3079 - val_dice_coef: 0.2338
# Epoch 13/70
# 10/10 [==============================] - ETA: 0s - loss: 1.5164 - dice_coef: 0.3641
# Epoch 13: loss improved from 1.58840 to 1.51637, saving model to super_model.h5
# 10/10 [==============================] - 4s 455ms/step - loss: 1.5164 - dice_coef: 0.3641 - val_loss: 2.3472 - val_dice_coef: 0.2535
# Epoch 14/70
# 10/10 [==============================] - ETA: 0s - loss: 1.4735 - dice_coef: 0.3804
# Epoch 14: loss improved from 1.51637 to 1.47348, saving model to super_model.h5
# 10/10 [==============================] - 4s 457ms/step - loss: 1.4735 - dice_coef: 0.3804 - val_loss: 2.3849 - val_dice_coef: 0.2698
# Epoch 15/70
# 10/10 [==============================] - ETA: 0s - loss: 1.4292 - dice_coef: 0.3972
# Epoch 15: loss improved from 1.47348 to 1.42925, saving model to super_model.h5
# 10/10 [==============================] - 5s 478ms/step - loss: 1.4292 - dice_coef: 0.3972 - val_loss: 2.4449 - val_dice_coef: 0.2855
# Epoch 16/70
# 10/10 [==============================] - ETA: 0s - loss: 1.3739 - dice_coef: 0.4226
# Epoch 16: loss improved from 1.42925 to 1.37387, saving model to super_model.h5
# 10/10 [==============================] - 4s 458ms/step - loss: 1.3739 - dice_coef: 0.4226 - val_loss: 2.4933 - val_dice_coef: 0.2972
# Epoch 17/70
# 10/10 [==============================] - ETA: 0s - loss: 1.3466 - dice_coef: 0.4344
# Epoch 17: loss improved from 1.37387 to 1.34665, saving model to super_model.h5
# 10/10 [==============================] - 4s 457ms/step - loss: 1.3466 - dice_coef: 0.4344 - val_loss: 2.5600 - val_dice_coef: 0.3070
# Epoch 18/70
# 10/10 [==============================] - ETA: 0s - loss: 1.3103 - dice_coef: 0.4449
# Epoch 18: loss improved from 1.34665 to 1.31028, saving model to super_model.h5
# 10/10 [==============================] - 5s 481ms/step - loss: 1.3103 - dice_coef: 0.4449 - val_loss: 2.5997 - val_dice_coef: 0.3140
# Epoch 19/70
# 10/10 [==============================] - ETA: 0s - loss: 1.3188 - dice_coef: 0.4508
# Epoch 19: loss did not improve from 1.31028
# 10/10 [==============================] - 4s 446ms/step - loss: 1.3188 - dice_coef: 0.4508 - val_loss: 2.6989 - val_dice_coef: 0.3240
# Epoch 20/70
# 10/10 [==============================] - ETA: 0s - loss: 1.2822 - dice_coef: 0.4667
# Epoch 20: loss improved from 1.31028 to 1.28216, saving model to super_model.h5
# 10/10 [==============================] - 4s 460ms/step - loss: 1.2822 - dice_coef: 0.4667 - val_loss: 2.7823 - val_dice_coef: 0.3319
# Epoch 21/70
# 10/10 [==============================] - ETA: 0s - loss: 1.2535 - dice_coef: 0.4760
# Epoch 21: loss improved from 1.28216 to 1.25348, saving model to super_model.h5
# 10/10 [==============================] - 4s 457ms/step - loss: 1.2535 - dice_coef: 0.4760 - val_loss: 2.8206 - val_dice_coef: 0.3363
# Epoch 22/70
# 10/10 [==============================] - ETA: 0s - loss: 1.2455 - dice_coef: 0.4807
# Epoch 22: loss improved from 1.25348 to 1.24552, saving model to super_model.h5
# 10/10 [==============================] - 4s 456ms/step - loss: 1.2455 - dice_coef: 0.4807 - val_loss: 2.8797 - val_dice_coef: 0.3408
# Epoch 23/70
# 10/10 [==============================] - ETA: 0s - loss: 1.2170 - dice_coef: 0.4926
# Epoch 23: loss improved from 1.24552 to 1.21700, saving model to super_model.h5
# 10/10 [==============================] - 5s 479ms/step - loss: 1.2170 - dice_coef: 0.4926 - val_loss: 2.9499 - val_dice_coef: 0.3452
# Epoch 24/70
# 10/10 [==============================] - ETA: 0s - loss: 1.2075 - dice_coef: 0.4968
# Epoch 24: loss improved from 1.21700 to 1.20755, saving model to super_model.h5
# 10/10 [==============================] - 4s 459ms/step - loss: 1.2075 - dice_coef: 0.4968 - val_loss: 2.9568 - val_dice_coef: 0.3473
# Epoch 25/70
# 10/10 [==============================] - ETA: 0s - loss: 1.1848 - dice_coef: 0.5031
# Epoch 25: loss improved from 1.20755 to 1.18483, saving model to super_model.h5
# 10/10 [==============================] - 4s 460ms/step - loss: 1.1848 - dice_coef: 0.5031 - val_loss: 3.0033 - val_dice_coef: 0.3509
# Epoch 26/70
# 10/10 [==============================] - ETA: 0s - loss: 1.1734 - dice_coef: 0.5095
# Epoch 26: loss improved from 1.18483 to 1.17336, saving model to super_model.h5
# 10/10 [==============================] - 5s 481ms/step - loss: 1.1734 - dice_coef: 0.5095 - val_loss: 3.0049 - val_dice_coef: 0.3530
# Epoch 27/70
# 10/10 [==============================] - ETA: 0s - loss: 1.1711 - dice_coef: 0.5106
# Epoch 27: loss improved from 1.17336 to 1.17112, saving model to super_model.h5
# 10/10 [==============================] - 4s 462ms/step - loss: 1.1711 - dice_coef: 0.5106 - val_loss: 3.0535 - val_dice_coef: 0.3575
# Epoch 28/70
# 10/10 [==============================] - ETA: 0s - loss: 1.1579 - dice_coef: 0.5182
# Epoch 28: loss improved from 1.17112 to 1.15787, saving model to super_model.h5
# 10/10 [==============================] - 4s 458ms/step - loss: 1.1579 - dice_coef: 0.5182 - val_loss: 3.0273 - val_dice_coef: 0.3590
# Epoch 29/70
# 10/10 [==============================] - ETA: 0s - loss: 1.1282 - dice_coef: 0.5234
# Epoch 29: loss improved from 1.15787 to 1.12822, saving model to super_model.h5
# 10/10 [==============================] - 4s 456ms/step - loss: 1.1282 - dice_coef: 0.5234 - val_loss: 3.1038 - val_dice_coef: 0.3642
# Epoch 30/70
# 10/10 [==============================] - ETA: 0s - loss: 1.1260 - dice_coef: 0.5283
# Epoch 30: loss improved from 1.12822 to 1.12604, saving model to super_model.h5
# 10/10 [==============================] - 4s 462ms/step - loss: 1.1260 - dice_coef: 0.5283 - val_loss: 3.1548 - val_dice_coef: 0.3669
# Epoch 31/70
# 10/10 [==============================] - ETA: 0s - loss: 1.1138 - dice_coef: 0.5325
# Epoch 31: loss improved from 1.12604 to 1.11379, saving model to super_model.h5
# 10/10 [==============================] - 4s 458ms/step - loss: 1.1138 - dice_coef: 0.5325 - val_loss: 3.1340 - val_dice_coef: 0.3691
# Epoch 32/70
# 10/10 [==============================] - ETA: 0s - loss: 1.1139 - dice_coef: 0.5323
# Epoch 32: loss did not improve from 1.11379
# 10/10 [==============================] - 4s 448ms/step - loss: 1.1139 - dice_coef: 0.5323 - val_loss: 3.0656 - val_dice_coef: 0.3745
# Epoch 33/70
# 10/10 [==============================] - ETA: 0s - loss: 1.0876 - dice_coef: 0.5384
# Epoch 33: loss improved from 1.11379 to 1.08761, saving model to super_model.h5
# 10/10 [==============================] - 4s 458ms/step - loss: 1.0876 - dice_coef: 0.5384 - val_loss: 2.9251 - val_dice_coef: 0.3765
# Epoch 34/70
# 10/10 [==============================] - ETA: 0s - loss: 1.0763 - dice_coef: 0.5442
# Epoch 34: loss improved from 1.08761 to 1.07631, saving model to super_model.h5
# 10/10 [==============================] - 5s 480ms/step - loss: 1.0763 - dice_coef: 0.5442 - val_loss: 3.0530 - val_dice_coef: 0.3779
# Epoch 35/70
# 10/10 [==============================] - ETA: 0s - loss: 1.0564 - dice_coef: 0.5502
# Epoch 35: loss improved from 1.07631 to 1.05636, saving model to super_model.h5
# 10/10 [==============================] - 4s 457ms/step - loss: 1.0564 - dice_coef: 0.5502 - val_loss: 3.0945 - val_dice_coef: 0.3800
# Epoch 36/70
# 10/10 [==============================] - ETA: 0s - loss: 1.0560 - dice_coef: 0.5543
# Epoch 36: loss improved from 1.05636 to 1.05598, saving model to super_model.h5
# 10/10 [==============================] - 5s 485ms/step - loss: 1.0560 - dice_coef: 0.5543 - val_loss: 2.9331 - val_dice_coef: 0.3822
# Epoch 37/70
# 10/10 [==============================] - ETA: 0s - loss: 1.0911 - dice_coef: 0.5427
# Epoch 37: loss did not improve from 1.05598
# 10/10 [==============================] - 4s 447ms/step - loss: 1.0911 - dice_coef: 0.5427 - val_loss: 2.9993 - val_dice_coef: 0.3855
# Epoch 38/70
# 10/10 [==============================] - ETA: 0s - loss: 1.0339 - dice_coef: 0.5597
# Epoch 38: loss improved from 1.05598 to 1.03387, saving model to super_model.h5
# 10/10 [==============================] - 4s 463ms/step - loss: 1.0339 - dice_coef: 0.5597 - val_loss: 2.8422 - val_dice_coef: 0.3896
# Epoch 39/70
# 10/10 [==============================] - ETA: 0s - loss: 1.0540 - dice_coef: 0.5552
# Epoch 39: loss did not improve from 1.03387
# 10/10 [==============================] - 4s 445ms/step - loss: 1.0540 - dice_coef: 0.5552 - val_loss: 2.9156 - val_dice_coef: 0.3895
# Epoch 40/70
# 10/10 [==============================] - ETA: 0s - loss: 1.0289 - dice_coef: 0.5599
# Epoch 40: loss improved from 1.03387 to 1.02886, saving model to super_model.h5
# 10/10 [==============================] - 4s 458ms/step - loss: 1.0289 - dice_coef: 0.5599 - val_loss: 2.6843 - val_dice_coef: 0.3973
# Epoch 41/70
# 10/10 [==============================] - ETA: 0s - loss: 1.0124 - dice_coef: 0.5672
# Epoch 41: loss improved from 1.02886 to 1.01243, saving model to super_model.h5
# 10/10 [==============================] - 4s 457ms/step - loss: 1.0124 - dice_coef: 0.5672 - val_loss: 2.4458 - val_dice_coef: 0.4079
# Epoch 42/70
# 10/10 [==============================] - ETA: 0s - loss: 1.0406 - dice_coef: 0.5578
# Epoch 42: loss did not improve from 1.01243
# 10/10 [==============================] - 4s 447ms/step - loss: 1.0406 - dice_coef: 0.5578 - val_loss: 2.6412 - val_dice_coef: 0.4024
# Epoch 43/70
# 10/10 [==============================] - ETA: 0s - loss: 0.9992 - dice_coef: 0.5716
# Epoch 43: loss improved from 1.01243 to 0.99916, saving model to super_model.h5
# 10/10 [==============================] - 4s 459ms/step - loss: 0.9992 - dice_coef: 0.5716 - val_loss: 2.7079 - val_dice_coef: 0.3998
# Epoch 44/70
# 10/10 [==============================] - ETA: 0s - loss: 0.9913 - dice_coef: 0.5736
# Epoch 44: loss improved from 0.99916 to 0.99133, saving model to super_model.h5
# 10/10 [==============================] - 5s 482ms/step - loss: 0.9913 - dice_coef: 0.5736 - val_loss: 2.5559 - val_dice_coef: 0.4091
# Epoch 45/70
# 10/10 [==============================] - ETA: 0s - loss: 0.9971 - dice_coef: 0.5759
# Epoch 45: loss did not improve from 0.99133
# 10/10 [==============================] - 4s 448ms/step - loss: 0.9971 - dice_coef: 0.5759 - val_loss: 2.5167 - val_dice_coef: 0.4081
# Epoch 46/70
# 10/10 [==============================] - ETA: 0s - loss: 0.9910 - dice_coef: 0.5765
# Epoch 46: loss improved from 0.99133 to 0.99102, saving model to super_model.h5
# 10/10 [==============================] - 5s 481ms/step - loss: 0.9910 - dice_coef: 0.5765 - val_loss: 2.6040 - val_dice_coef: 0.4145
# Epoch 47/70
# 10/10 [==============================] - ETA: 0s - loss: 0.9755 - dice_coef: 0.5796
# Epoch 47: loss improved from 0.99102 to 0.97548, saving model to super_model.h5
# 10/10 [==============================] - 5s 479ms/step - loss: 0.9755 - dice_coef: 0.5796 - val_loss: 2.2361 - val_dice_coef: 0.4238
# Epoch 48/70
# 10/10 [==============================] - ETA: 0s - loss: 0.9865 - dice_coef: 0.5807
# Epoch 48: loss did not improve from 0.97548
# 10/10 [==============================] - 4s 447ms/step - loss: 0.9865 - dice_coef: 0.5807 - val_loss: 2.2461 - val_dice_coef: 0.4211
# Epoch 49/70
# 10/10 [==============================] - ETA: 0s - loss: 0.9639 - dice_coef: 0.5868
# Epoch 49: loss improved from 0.97548 to 0.96393, saving model to super_model.h5
# 10/10 [==============================] - 4s 457ms/step - loss: 0.9639 - dice_coef: 0.5868 - val_loss: 2.4464 - val_dice_coef: 0.4178
# Epoch 50/70
# 10/10 [==============================] - ETA: 0s - loss: 0.9577 - dice_coef: 0.5860
# Epoch 50: loss improved from 0.96393 to 0.95771, saving model to super_model.h5
# 10/10 [==============================] - 4s 457ms/step - loss: 0.9577 - dice_coef: 0.5860 - val_loss: 2.4288 - val_dice_coef: 0.4163
# Epoch 51/70
# 10/10 [==============================] - ETA: 0s - loss: 0.9470 - dice_coef: 0.5886
# Epoch 51: loss improved from 0.95771 to 0.94696, saving model to super_model.h5
# 10/10 [==============================] - 5s 478ms/step - loss: 0.9470 - dice_coef: 0.5886 - val_loss: 2.3472 - val_dice_coef: 0.4262
# Epoch 52/70
# 10/10 [==============================] - ETA: 0s - loss: 0.9498 - dice_coef: 0.5922
# Epoch 52: loss did not improve from 0.94696
# 10/10 [==============================] - 4s 445ms/step - loss: 0.9498 - dice_coef: 0.5922 - val_loss: 1.9992 - val_dice_coef: 0.4356
# Epoch 53/70
# 10/10 [==============================] - ETA: 0s - loss: 0.9207 - dice_coef: 0.6019
# Epoch 53: loss improved from 0.94696 to 0.92067, saving model to super_model.h5
# 10/10 [==============================] - 4s 460ms/step - loss: 0.9207 - dice_coef: 0.6019 - val_loss: 1.6638 - val_dice_coef: 0.4620
# Epoch 54/70
# 10/10 [==============================] - ETA: 0s - loss: 0.9404 - dice_coef: 0.5948
# Epoch 54: loss did not improve from 0.92067
# 10/10 [==============================] - 4s 425ms/step - loss: 0.9404 - dice_coef: 0.5948 - val_loss: 2.1464 - val_dice_coef: 0.4414
# Epoch 55/70
# 10/10 [==============================] - ETA: 0s - loss: 0.9254 - dice_coef: 0.6026
# Epoch 55: loss did not improve from 0.92067
# 10/10 [==============================] - 4s 424ms/step - loss: 0.9254 - dice_coef: 0.6026 - val_loss: 2.4257 - val_dice_coef: 0.4222
# Epoch 56/70
# 10/10 [==============================] - ETA: 0s - loss: 0.9327 - dice_coef: 0.6009
# Epoch 56: loss did not improve from 0.92067
# 10/10 [==============================] - 4s 426ms/step - loss: 0.9327 - dice_coef: 0.6009 - val_loss: 1.9074 - val_dice_coef: 0.4334
# Epoch 57/70
# 10/10 [==============================] - ETA: 0s - loss: 0.9062 - dice_coef: 0.6051
# Epoch 57: loss improved from 0.92067 to 0.90621, saving model to super_model.h5
# 10/10 [==============================] - 5s 480ms/step - loss: 0.9062 - dice_coef: 0.6051 - val_loss: 1.9682 - val_dice_coef: 0.4622
# Epoch 58/70
# 10/10 [==============================] - ETA: 0s - loss: 0.9576 - dice_coef: 0.5935
# Epoch 58: loss did not improve from 0.90621
# 10/10 [==============================] - 4s 426ms/step - loss: 0.9576 - dice_coef: 0.5935 - val_loss: 2.1921 - val_dice_coef: 0.4416
# Epoch 59/70
# 10/10 [==============================] - ETA: 0s - loss: 0.9157 - dice_coef: 0.6038
# Epoch 59: loss did not improve from 0.90621
# 10/10 [==============================] - 4s 425ms/step - loss: 0.9157 - dice_coef: 0.6038 - val_loss: 1.9601 - val_dice_coef: 0.4539
# Epoch 60/70
# 10/10 [==============================] - ETA: 0s - loss: 0.8945 - dice_coef: 0.6081
# Epoch 60: loss improved from 0.90621 to 0.89452, saving model to super_model.h5
# 10/10 [==============================] - 5s 481ms/step - loss: 0.8945 - dice_coef: 0.6081 - val_loss: 1.7612 - val_dice_coef: 0.4712
# Epoch 61/70
# 10/10 [==============================] - ETA: 0s - loss: 0.9137 - dice_coef: 0.6049
# Epoch 61: loss did not improve from 0.89452
# 10/10 [==============================] - 4s 424ms/step - loss: 0.9137 - dice_coef: 0.6049 - val_loss: 1.5519 - val_dice_coef: 0.5008
# Epoch 62/70
# 10/10 [==============================] - ETA: 0s - loss: 0.8743 - dice_coef: 0.6159
# Epoch 62: loss improved from 0.89452 to 0.87433, saving model to super_model.h5
# 10/10 [==============================] - 4s 459ms/step - loss: 0.8743 - dice_coef: 0.6159 - val_loss: 1.4625 - val_dice_coef: 0.5103
# Epoch 63/70
# 10/10 [==============================] - ETA: 0s - loss: 0.8837 - dice_coef: 0.6123
# Epoch 63: loss did not improve from 0.87433
# 10/10 [==============================] - 4s 445ms/step - loss: 0.8837 - dice_coef: 0.6123 - val_loss: 1.5368 - val_dice_coef: 0.5052
# Epoch 64/70
# 10/10 [==============================] - ETA: 0s - loss: 0.8706 - dice_coef: 0.6191
# Epoch 64: loss improved from 0.87433 to 0.87064, saving model to super_model.h5
# 10/10 [==============================] - 5s 479ms/step - loss: 0.8706 - dice_coef: 0.6191 - val_loss: 1.3164 - val_dice_coef: 0.5350
# Epoch 65/70
# 10/10 [==============================] - ETA: 0s - loss: 0.8848 - dice_coef: 0.6190
# Epoch 65: loss did not improve from 0.87064
# 10/10 [==============================] - 4s 425ms/step - loss: 0.8848 - dice_coef: 0.6190 - val_loss: 1.3874 - val_dice_coef: 0.5137
# Epoch 66/70
# 10/10 [==============================] - ETA: 0s - loss: 0.8664 - dice_coef: 0.6222
# Epoch 66: loss improved from 0.87064 to 0.86640, saving model to super_model.h5
# 10/10 [==============================] - 5s 480ms/step - loss: 0.8664 - dice_coef: 0.6222 - val_loss: 1.2811 - val_dice_coef: 0.5278
# Epoch 67/70
# 10/10 [==============================] - ETA: 0s - loss: 0.8515 - dice_coef: 0.6256
# Epoch 67: loss improved from 0.86640 to 0.85150, saving model to super_model.h5
# 10/10 [==============================] - 5s 479ms/step - loss: 0.8515 - dice_coef: 0.6256 - val_loss: 1.3000 - val_dice_coef: 0.5288
# Epoch 68/70
# 10/10 [==============================] - ETA: 0s - loss: 0.8500 - dice_coef: 0.6294
# Epoch 68: loss improved from 0.85150 to 0.85001, saving model to super_model.h5
# 10/10 [==============================] - 5s 480ms/step - loss: 0.8500 - dice_coef: 0.6294 - val_loss: 1.5600 - val_dice_coef: 0.5020
# Epoch 69/70
# 10/10 [==============================] - ETA: 0s - loss: 0.8333 - dice_coef: 0.6335
# Epoch 69: loss improved from 0.85001 to 0.83327, saving model to super_model.h5
# 10/10 [==============================] - 5s 482ms/step - loss: 0.8333 - dice_coef: 0.6335 - val_loss: 1.6379 - val_dice_coef: 0.4702
# Epoch 70/70
# 10/10 [==============================] - ETA: 0s - loss: 0.8462 - dice_coef: 0.6269
# Epoch 70: loss did not improve from 0.83327
# 10/10 [==============================] - 4s 425ms/step - loss: 0.8462 - dice_coef: 0.6269 - val_loss: 1.2577 - val_dice_coef: 0.5324
# CPU times: user 5min 14s, sys: 7.69 s, total: 5min 21s
# Wall time: 5min 25s

# %%
plt.figure(figsize=(18, 9))
plt.plot(history.history['val_dice_coef'],label = 'test')
plt.plot(history.history['dice_coef'],label='train')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('dice_coef')
plt.show()

# %%
pred = super_model.predict(X_val)

# %%
class_ = 11
fig, axes = plt.subplots(1, 4, figsize=(18, 9))
axes[0].imshow(X_val[5])
axes[0].title.set_text('входной кадр')
axes[1].imshow(y_val[5])
axes[1].title.set_text('целевая разметка')
axes[2].imshow(val_labels[5][:,:,class_])
axes[2].title.set_text('целевая разметка класс: '+str(class_))
axes[3].imshow(pred[5][:,:,class_])
axes[3].title.set_text('предиктивная разметка класс: '+str(class_))
plt.show()

# %% [markdown]
# Улучшить метрику получилось, увеличив количество пар слоев, уменьшив количество ядер первого и последующих слоев. Также помогло - изменение оптимизатора и тюнинг скорости обучения.
#
# Кроме того, видно, что последующее увеличение количества эпох может привести к улучшению модели.
